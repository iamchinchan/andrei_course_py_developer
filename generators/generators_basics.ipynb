# %%
max(range(5))
# Out:
# 4

# %%
def gen_fn(n):
    for i in range(n):
        yield i**2


n = 10
g = gen_fn(n)

# %%
print(g)
# Out:
# <generator object gen_fn at 0x000001DC26AA9560>

# %%
print(list(g))
print(list(g))
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# []

# %%
g = gen_fn(n)

# %%
n = 5

# %%
list(g)
list(g)
# Out:
# []

# %%
g = gen_fn(n)
print(next(g))
print(next(g))
print(list(g))
print(list(g))
# Out:
# 0
# 1
# [4, 9, 16]
# []

# %%
def s_gn():
    yield 5

# %%
g = s_gn()
print(g)
print(list(g))
print(list(g))
# Out:
# <generator object s_gn at 0x000001DC25137100>
# [5]
# []
