# %%
def sm(n1, n2):
    try:
        return n1 + n2
    except TypeError as err:
        print(f"Please eneter a number: {err}")
    else:
        printf("Succefully done!")
        # in this case it wont ever run as if succefull it will return immediately after running finally

    finally:
        print(f"I always run!!")


print(sm(1, 2))
# Out:
# I always run!!
# 3

# %%
print(sm(1, "2"))
# Out:
# Please eneter a number: unsupported operand type(s) for +: 'int' and 'str'
# I always run!!
# None

# %%
print(sm("a", "f"))
print(sm("1", "2"))
# Out:
# I always run!!
# af
# I always run!!
# 12
