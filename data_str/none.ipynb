# %%
n = None
print(n)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
# absence of value

# %%
if None:
    print("Truthsy")
else:
    print("Falsy value")
# Out:
# Falsy value

# %%
# its a falsy value

# %%
print(None == None)  # True
# Out:
# True

# %%
print(None)
# Out:
# None
