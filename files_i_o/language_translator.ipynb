# %%
from googletrans import Translator
# Out:
# Hello world

# %%
translator = Translator()

# %%
with open("native.txt", "r") as native:
    with open("converted.txt", "w") as t:
        extracted = native.read()
        converted = await translator.translate(extracted, dest="es")
        t.write(converted.text)
