# %%
import sys

# %%
sys.executable
# Out:
# 'j:\\Development\\Python\\Anaconda\\envs\\andrei_py_developer\\python.exe'

# %%
import sys

print(sys.version)
# Out:
# 3.14.4 | packaged by Anaconda, Inc. | (main, Apr 14 2026, 17:00:17) [MSC v.1942 64 bit (AMD64)]

# %%
# !pip --version
# Out:
# pip 26.0.1 from J:\Development\Python\Anaconda\envs\andrei_py_developer\Lib\site-packages\pip (python 3.14)

# %%
print("Hey there:  from vs code")
# Out:
# Hey there:  from vs code

# %%
print("hey there from jupyter")
# Out:
# hey there from jupyter

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
print(a)
# Out:
# 10
