print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x1FD87A5ACF0>

# %%
img.show()

# %%
img.save("random.robot.png")

# %%
url = "https://swapi.dev/api/people/1"
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers)
# Out:
# {'Content-Type': 'application/json', 'Content-Length': '647', 'Connection': 'keep-alive', 'Date': 'Wed, 08 Jul 2026 11:35:50 GMT', 'X-Amzn-Trace-Id': 'Root=1-6a4e3616-2fe1bf7705acb29c7e421c32;Parent=3996a68ed57accbe;Sampled=0;Lineage=1:a92a9227:0', 'x-amzn-RequestId': '9ce8e270-64e3-42cf-a4ce-b362f3d63686', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 5ebf576d12f6509b8dd71a69aebcb490.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'MRS52-P5', 'X-Amz-Cf-Id': 'u8_pEz-EGpBe8JBJPpx8GvLjlCCZBHYnQw2OYl6IKErFyiQY9pg53A==', 'Age': '16958', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=15768000', 'Vary': 'Origin'}

# %%
print(response.content)
# Out:
# b'{"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/14/","https://swapi.dev/api/vehicles/30/"],"starships":["https://swapi.dev/api/starships/12/","https://swapi.dev/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"https://swapi.dev/api/people/1/"}'

# %%
print(response.text)
# Out:
# {"name":"Luke Skywalker","height":"172","mass":"77","hair_color":"blond","skin_color":"fair","eye_color":"blue","birth_year":"19BBY","gender":"male","homeworld":"https://swapi.dev/api/planets/1/","films":["https://swapi.dev/api/films/1/","https://swapi.dev/api/films/2/","https://swapi.dev/api/films/3/","https://swapi.dev/api/films/6/"],"species":[],"vehicles":["https://swapi.dev/api/vehicles/14/","https://swapi.dev/api/vehicles/30/"],"starships":["https://swapi.dev/api/starships/12/","https://swapi.dev/api/starships/22/"],"created":"2014-12-09T13:50:51.644000Z","edited":"2014-12-20T21:17:56.891000Z","url":"https://swapi.dev/api/people/1/"}

# %%
print(type(response.content))
print(type(response.text))
# Out:
# <class 'bytes'>
# <class 'str'>

# %%
import json

# Converts the string into a dictionary
data = json.loads(response.text)

# %%
print(data)
# Out:
# {'name': 'Luke Skywalker', 'height': '172', 'mass': '77', 'hair_color': 'blond', 'skin_color': 'fair', 'eye_color': 'blue', 'birth_year': '19BBY', 'gender': 'male', 'homeworld': 'https://swapi.dev/api/planets/1/', 'films': ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/6/'], 'species': [], 'vehicles': ['https://swapi.dev/api/vehicles/14/', 'https://swapi.dev/api/vehicles/30/'], 'starships': ['https://swapi.dev/api/starships/12/', 'https://swapi.dev/api/starships/22/'], 'created': '2014-12-09T13:50:51.644000Z', 'edited': '2014-12-20T21:17:56.891000Z', 'url': 'https://swapi.dev/api/people/1/'}

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
data = response.json()
print(type(data))
print(data)
# we can do thjis bcz of requests response object has a built-in method called json() that automatically parses the JSON content and returns it as a Python dictionary. This is a convenient way to work with JSON data without having to manually convert it using the json module.
# Out:
# <class 'dict'>
# {'name': 'Luke Skywalker', 'height': '172', 'mass': '77', 'hair_color': 'blond', 'skin_color': 'fair', 'eye_color': 'blue', 'birth_year': '19BBY', 'gender': 'male', 'homeworld': 'https://swapi.dev/api/planets/1/', 'films': ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/6/'], 'species': [], 'vehicles': ['https://swapi.dev/api/vehicles/14/', 'https://swapi.dev/api/vehicles/30/'], 'starships': ['https://swapi.dev/api/starships/12/', 'https://swapi.dev/api/starships/22/'], 'created': '2014-12-09T13:50:51.644000Z', 'edited': '2014-12-20T21:17:56.891000Z', 'url': 'https://swapi.dev/api/people/1/'}

# %%
print(data["name"])
# Out:
# Luke Skywalker

# %%
[key for key in data.keys()]
# Out:
# ['name',
#  'height',
#  'mass',
#  'hair_color',
#  'skin_color',
#  'eye_color',
#  'birth_year',
#  'gender',
#  'homeworld',
#  'films',
#  'species',
#  'vehicles',
#  'starships',
#  'created',
#  'edited',
#  'url']

# %%
data.keys
# Out:
# <function dict.keys()>

# %%
data.keys()
# Out:
# dict_keys(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color', 'birth_year', 'gender', 'homeworld', 'films', 'species', 'vehicles', 'starships', 'created', 'edited', 'url'])

# %%
print(data.keys())
# Out:
# dict_keys(['name', 'height', 'mass', 'hair_color', 'skin_color', 'eye_color', 'birth_year', 'gender', 'homeworld', 'films', 'species', 'vehicles', 'starships', 'created', 'edited', 'url'])

# %%
data.values()
# Out:
# dict_values(['Luke Skywalker', '172', '77', 'blond', 'fair', 'blue', '19BBY', 'male', 'https://swapi.dev/api/planets/1/', ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/6/'], [], ['https://swapi.dev/api/vehicles/14/', 'https://swapi.dev/api/vehicles/30/'], ['https://swapi.dev/api/starships/12/', 'https://swapi.dev/api/starships/22/'], '2014-12-09T13:50:51.644000Z', '2014-12-20T21:17:56.891000Z', 'https://swapi.dev/api/people/1/'])

# %%
data.items()
# Out:
# dict_items([('name', 'Luke Skywalker'), ('height', '172'), ('mass', '77'), ('hair_color', 'blond'), ('skin_color', 'fair'), ('eye_color', 'blue'), ('birth_year', '19BBY'), ('gender', 'male'), ('homeworld', 'https://swapi.dev/api/planets/1/'), ('films', ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/6/']), ('species', []), ('vehicles', ['https://swapi.dev/api/vehicles/14/', 'https://swapi.dev/api/vehicles/30/']), ('starships', ['https://swapi.dev/api/starships/12/', 'https://swapi.dev/api/starships/22/']), ('created', '2014-12-09T13:50:51.644000Z'), ('edited', '2014-12-20T21:17:56.891000Z'), ('url', 'https://swapi.dev/api/people/1/')])
