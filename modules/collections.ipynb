# %%
from collections import Counter, defaultdict, OrderedDict

# %%
print(Counter("Abra ka dabra"))
# Out:
# Counter({'a': 4, 'b': 2, 'r': 2, ' ': 2, 'A': 1, 'k': 1, 'd': 1})

# %%
d = defaultdict()

# %%
print(d)
# Out:
# defaultdict(None, {})

# %%
d.update({"age": 25})

# %%
d
# Out:
# defaultdict(None, {'age': 25})

# %%
d["age"]
# Out:
# 25

# %%
d["a"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 d["a"]
#
# KeyError: 'a'

# %%
d1 = defaultdict(lambda: f"Does not exist", d)

# %%
d1
# Out:
# defaultdict(<function __main__.<lambda>()>, {'age': 25})

# %%
d is d1
# Out:
# False

# %%
id(d), id(d1)
# Out:
# (2047995516768, 2047994920720)

# %%
d.update({"name": "Jatin"})

# %%
d
# Out:
# defaultdict(None, {'age': 25, 'name': 'Jatin'})

# %%
d1
# Out:
# defaultdict(<function __main__.<lambda>()>, {'age': 25})

# %%
d["name"]
# Out:
# 'Jatin'

# %%
d1["name"]
# Out:
# 'Does not exist'

# %%
d1["age"]
# Out:
# 25

# %%
d1["name"] = "Shiv"

# %%
d1
# Out:
# defaultdict(<function __main__.<lambda>()>, {'age': 25, 'name': 'Shiv'})

# %%
d1 = {1: 1, 2: 2}
d2 = {2: 2, 1: 1}
d1 == d2
# Out:
# True

# %%
d1 = OrderedDict({1: 1, 2: 2})
d2 = OrderedDict({2: 2, 1: 1})
d1 == d2
# Out:
# False

# %%
d1
# Out:
# OrderedDict([(1, 1), (2, 2)])
