# %%
from time import time

print(time())
# Out:
# 1780297229.817781

# %%
import datetime

print(datetime.time())
print(datetime.time(5, 45, 6))
# Out:
# 00:00:00
# 05:45:06

# %%
print(datetime.date.today())
# Out:
# 2026-06-01
