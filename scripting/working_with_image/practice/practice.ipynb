# %%
from PIL import Image, ImageFilter

# %%
img = Image.open("astro.jpg","r")

# %%
img.size
# Out:
# (5611, 5339)

# %%
img.thumbnail((400,400))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x381>

# %%
img.size
# Out:
# (400, 381)

# %%
pwd
# Out:
# 'j:\\Development\\Python_courses\\andrei_python_fundamentals\\my_codes\\scripting\\working_with_image\\practice'
