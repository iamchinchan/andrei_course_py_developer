# %%
from PIL import Image
from pathlib import Path

# %%
path = Path("./pokedex/pikachu.jpg")
pika = Image.open(path)

# %%
pika
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
print(pika)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x1C1EF7916A0>

# %%
pika.format
# Out:
# 'JPEG'

# %%
pika.size
# Out:
# (640, 640)

# %%
pika.mode
# Out:
# 'RGB'

# %%
dir(pika)
# Out:
# ['_Image__transformer',
#  '__annotations__',
#  '__array_interface__',
#  '__arrow_c_array__',
#  '__arrow_c_schema__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attach_default_encoderinfo',
#  '_close_exclusive_fp_after_loading',
#  '_close_fp',
#  '_copy',
#  '_crop',
#  '_default_encoderinfo',
#  '_dump',
#  '_ensure_mutable',
#  '_exclusive_fp',
#  '_exif',
#  '_exif_offset',
#  '_get_safe_box',
#  '_getexif',
#  '_getmp',
#  '_huffman_ac',
#  '_huffman_dc',
#  '_im',
# ...

# %%
from PIL import ImageFilter
