# %%
1 + 1
# Out:
# 2

# %%
my_list = [1, 2, 3, 4, 5]
i = 0
while i < len(my_list):
    pass
    # pass even in the start does not do anything,
    #  it is just a placeholder for the code that will be written later.
    #  It is used to avoid syntax errors when the code block is empty.
    # print statement is still executed, even if the pass statement is present.
    print(my_list[i])
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
