# %%
'a' > 'A'
# Out:
# True

# %%
print(ord('A'))  # 65
print(ord('a'))  # 97
print(ord('b'))
# Out:
# 65
# 97
# 98

# %% [markdown]
# Python compares strings based on the Unicode values (which are identical to ASCII for standard letters).'A' = 65'a' = 97Because $97 > 65$, Python evaluates 'a' > 'A' as True.

# %%
not(True)
# Out:
# False

# %%
not True
# Out:
# False

# %%
is_magician = False
is_expert = False

# %%
if is_magician:
  if is_expert:
    print("You are a master magician")
  else:
    print("At you are getting there~!")
else:
  print("you need magic powers")
# Out:
# you need magic powers

# %%
print(True==1)
print(False==0)
print(""==1)
print(""==0)
print("0"==0)
print("1"==1)
print([]==1)
print([]==0)
print(10==10.0)
print([]==[])
print([1,2]==[1,2])
print([1,2]==1)
# Out:
# True
# True
# False
# False
# False
# False
# False
# False
# True
# True
# True
# False

# %%
True==5
# Out:
# False

# %%
True==bool(5)
# Out:
# True

# %%
if 5:
  print("Truthy")
# Out:
# Truthy

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(a == b)  # True, because they have the same values.
print(a is b)  # False, because they are two different lists in memory.
# Out:
# True
# False

# %%
'1' is '1'
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\goyal\AppData\Local\Temp\ipykernel_24872\1283835458.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   '1' is '1'
# True

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\goyal\AppData\Local\Temp\ipykernel_24872\1728060598.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   1 is 1
# True

# %%
[] is []
# Out:
# False

# %%
(1,2,3) ==(1,2,3)
# Out:
# True

# %%
print((1,2,3) is (1,2,3))
# Out:
# True
# <>:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# C:\Users\goyal\AppData\Local\Temp\ipykernel_24872\3994718979.py:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   print((1,2,3) is (1,2,3))

# %%
a=(1,2,3)
b=(1,2,3)

# %%
a==b
# Out:
# True

# %%
a is b
# Out:
# False
